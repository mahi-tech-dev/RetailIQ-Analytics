# %%
# ==========================================
# RetailIQ Analytics
# Milestone 2 - Data Loading & Understanding
# ==========================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset

df = pd.read_csv("../data/raw/superstore.csv")

print("Dataset loaded successfully!")

# %%
# First 5 Rows

df.head()

# %%
# Dataset Shape

print(df.shape)

# %%
# Dataset Information

df.info()

# %%
# Statistical Summary

df.describe()

# %%
# Missing Values

df.isnull().sum()

# %%
# Duplicate Rows

df.duplicated().sum()
